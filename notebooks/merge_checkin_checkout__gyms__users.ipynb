# %% [markdown]
# # Merge plan of checkin_checkout__gyms

# %%
import pandas as pd

# %%
checkin_checkout = pd.read_csv("../data/raw/checkin_checkout_history.csv")

checkin_checkout = checkin_checkout.replace(" ", None)
checkin_checkout = checkin_checkout.dropna()
checkin_checkout = checkin_checkout.astype(
    {
        "checkin_time": "datetime64[ns]",
        "checkout_time": "datetime64[ns]",
        "calories_burned": int,
    }
)

checkin_checkout = checkin_checkout.drop_duplicates()
checkin_checkout["user_id"] = checkin_checkout["user_id"].str.strip()
checkin_checkout["duration"] = (
    checkin_checkout["checkout_time"] - checkin_checkout["checkin_time"]
)

gyms = pd.read_csv("../data/raw/gym_locations_data.csv")

gyms = gyms.drop("facilities", axis=1)

merged_data1 = pd.merge(checkin_checkout, gyms, on="gym_id")
merged_data1.info()
merged_data1.shape
merged_data1.head()
# Out:
# (298500, 7)

# %%
users = pd.read_csv("../data/raw/users_data.csv")

users = users.replace(" ", None)
users = users.dropna()
users = users.astype(
    {
        "age": int,
        "sign_up_date": "datetime64[ns]",
    }
)
users = users.drop_duplicates()
users = users.drop("birthdate", axis=1)
users.info()
users.shape
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 0 to 5299
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            5000 non-null   object
#  1   first_name         5000 non-null   object
#  2   last_name          5000 non-null   object
#  3   age                5000 non-null   int64
#  4   gender             5000 non-null   object
#  5   sign_up_date       5000 non-null   datetime64[ns]
#  6   user_location      5000 non-null   object
#  7   subscription_plan  5000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 351.6+ KB
#      user_id first_name last_name  age  gender sign_up_date  user_location  \
# 0  user_1595       Mark  Phillips   55    Male   2023-03-20        Seattle
# 1  user_3596      Karen     Baker   52  Female   2023-06-21         Denver
# 2    user_25    Brandon    Walker   50    Male   2022-09-09  San Francisco
# 3   user_403     Daniel    Howard   39    Male   2022-04-22         Denver
# 4  user_1213  Stephanie     Lewis   24  Female   2022-10-24         Boston
#
#   subscription_plan
# 0               Pro
# 1             Basic
# 2           Student
# 3           Student
# 4             Basic

# %%
merged_data2 = pd.merge(users, merged_data1, on="user_id")
merged_data2.info()
merged_data2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298500 entries, 0 to 298499
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            298500 non-null  object
#  1   first_name         298500 non-null  object
#  2   last_name          298500 non-null  object
#  3   age                298500 non-null  int64
#  4   gender             298500 non-null  object
#  5   sign_up_date       298500 non-null  datetime64[ns]
#  6   user_location      298500 non-null  object
#  7   subscription_plan  298500 non-null  object
#  8   gym_id             298500 non-null  object
#  9   checkin_time       298500 non-null  datetime64[ns]
#  10  checkout_time      298500 non-null  datetime64[ns]
#  11  workout_type       298500 non-null  object
#  12  calories_burned    298500 non-null  int64
#  13  duration           298500 non-null  timedelta64[ns]
#  14  location           298500 non-null  object
#  15  gym_type           298500 non-null  object
# dtypes: datetime64[ns](3), int64(2), object(10), timedelta64[ns](1)
# memory usage: 36.4+ MB
# (298500, 16)
