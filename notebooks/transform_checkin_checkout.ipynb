# %% [markdown]
# # Exploratory Data analysis of checkin_checkout

# %%
import pandas as pd

# %%
checkin_checkout = pd.read_csv("../data/raw/checkin_checkout_history.csv")

checkin_checkout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300058 entries, 0 to 300057
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          300058 non-null  object
#  1   gym_id           299826 non-null  object
#  2   checkin_time     299813 non-null  object
#  3   checkout_time    299779 non-null  object
#  4   workout_type     299812 non-null  object
#  5   calories_burned  299791 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 13.7+ MB

# %% [markdown]
# ### Nulls?

# %%
# Check for nulls
print(checkin_checkout.isnull().any(axis=1).sum())
print(checkin_checkout.shape)
# Out:
# 1269
# (300058, 6)

# %%
print("Number of missing values per column")
for col in checkin_checkout.columns:
    print(f"{col}: {checkin_checkout[col].isnull().sum()}")
# Out:
# Number of missing values per column
# user_id: 0
# gym_id: 232
# checkin_time: 245
# checkout_time: 279
# workout_type: 246
# calories_burned: 267

# %% [markdown]
# > 1269 ~ 0.5% (0.4229...%) -> Not a lot thus it can be removed

# %%
checkin_checkout = checkin_checkout.dropna()
print(checkin_checkout.isnull().any(axis=1).sum())
print(checkin_checkout.shape)
# Out:
# 0
# (298789, 6)
